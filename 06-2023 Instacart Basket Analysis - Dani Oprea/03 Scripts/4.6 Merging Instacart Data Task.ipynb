# %% [markdown]
# Contents
#
# 01. Importing Libraries
# 02. Importing Data Sets
# 03. Merging Dataframes
# 04. Exporting

# %% [markdown]
# # 01. Importing Libraries

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data Sets

# %%
# Set path

path = r'/Users/danioprea/Desktop/Data Analytics/06-2023 Instacart Basket Analysis'

# %%
# Import orders_products_combined.pkl

df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods.shape
# Out:
# (32434489, 11)

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %%
df_ords_prods_1 = df_ords_prods.drop('_merge', axis=1)

# %%
df_ords_prods_1.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Import products_checked.csv

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Delete Unnamed column

df_prods = df_prods.drop('Unnamed: 0', axis=1)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods.shape
# Out:
# (49672, 5)

# %% [markdown]
# # 03. Merging Dataframes

# %%
# Merge the dataframes with an inner join

df_merged_1 = df_prods.merge(df_ords_prods_1, on = 'product_id', indicator = True)

# %%
df_merged_1.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df_merged_1.shape
# Out:
# (32404859, 15)

# %%
# Check _merge column of the merged dataframe

df_merged_1['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # 04. Exporting

# %%
# Export the merged dataframe to orders_products_merged.pkl

df_merged_1.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
