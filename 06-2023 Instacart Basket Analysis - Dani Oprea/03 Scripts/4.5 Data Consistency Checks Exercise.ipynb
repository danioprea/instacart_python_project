# %% [markdown]
# Contents
#
# 01. Importing Libraries
# 02. Importing Data Sets
# 03. Mixed-Type Columns
# 04. Missing Values
# 05. Duplicates
# 06. Task

# %% [markdown]
# # 01. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data Sets

# %%
path = r'/Users/danioprea/Desktop/Data Analytics/06-2023 Instacart Basket Analysis'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %% [markdown]
# # 03. Mixed-Type Columns

# %%
# Create a dataframe
df_test = pd.DataFrame()

# %%
# Create a mixed type column

df_test['mix'] = ['a', 'b', 1, True]
df_test['mix2'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix  mix2
# 0     a     a
# 1     b     b
# 2     1     1
# 3  True  True

# %%
# Check for mixed types

for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# mix2

# %%
# Convert to string type
df_test['mix'] = df_test['mix'].astype('str')

# %%
# Re-check to see if mix has been fixed

for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)

# %% [markdown]
# # 04. Missing Values

# %%
# Check for missing values

df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# Create a subset to view the missing values

df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# Checking the number of rows of df_prods

df_prods.shape
# Out:
# (49693, 5)

# %%
# Time to remove the rows with missing values

df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
# Check the new df_prods_clean

df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# # 05. Duplicates

# %%
# Finding duplicates

df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# Check the shape before deleting

df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# Create a new dataframe without the duplicate rows

df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# Check the new dataframe

df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
# Exporting the checked products dataframe

df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # 06. Task

# %%
# Step 2)

df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# Nothing looks off or seems like it should be investigated further.

# %%
# Step 3)

for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %%
# Step 4)

# No mixed-type data was found.

# %%
# Step 5)

df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords.head(30)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0            0   2539329        1    prior             1                   2
# 1            1   2398795        1    prior             2                   3
# 2            2    473747        1    prior             3                   3
# 3            3   2254736        1    prior             4                   4
# 4            4    431534        1    prior             5                   4
# 5            5   3367565        1    prior             6                   2
# 6            6    550135        1    prior             7                   1
# 7            7   3108588        1    prior             8                   1
# 8            8   2295261        1    prior             9                   1
# 9            9   2550362        1    prior            10                   4
# 10          10   1187899        1    train            11                   4
# ...

# %%
df_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_nan.head(30)
# Out:
#      Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 11           11   2168274        2    prior             1                   2
# 26           26   1374495        3    prior             1                   1
# 39           39   3343014        4    prior             1                   6
# 45           45   2717275        5    prior             1                   3
# 50           50   2086598        6    prior             1                   5
# 54           54   2565571        7    prior             1                   3
# 75           75    600894        8    prior             1                   6
# 79           79    280530        9    prior             1                   1
# 83           83   1224907       10    prior             1                   2
# 89           89   2411567       11    prior             1                   0
# ...

# %% [markdown]
# Step 5)
#
# It looks like we are missing values in the days_since_prior_order column. These seem to be for the first order that users place. It makes sense since the user has not existed in the system yet, there is no days since prior order as this is their first order.

# %% [markdown]
# Step 6)
#
# I have chosen to create a customer_status flag that shows whether a customer is a returning_customer or a new_customer.

# %%
df_ords['customer_status'] = df_ords.loc[:, 'days_since_prior_order']

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  customer_status
# 0                  8                     NaN              NaN
# 1                  7                    15.0             15.0
# 2                 12                    21.0             21.0
# 3                  7                    29.0             29.0
# 4                 15                    28.0             28.0

# %%
df_ords.loc[df_ords['customer_status'].notnull(), 'customer_status'] = 'returning_customer'

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order     customer_status
# 0                  8                     NaN                 NaN
# 1                  7                    15.0  returning_customer
# 2                 12                    21.0  returning_customer
# 3                  7                    29.0  returning_customer
# 4                 15                    28.0  returning_customer

# %%
df_ords['customer_status'] = df_ords['customer_status'].fillna('new_customer')

# %%
df_ords.head(30)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0            0   2539329        1    prior             1                   2
# 1            1   2398795        1    prior             2                   3
# 2            2    473747        1    prior             3                   3
# 3            3   2254736        1    prior             4                   4
# 4            4    431534        1    prior             5                   4
# 5            5   3367565        1    prior             6                   2
# 6            6    550135        1    prior             7                   1
# 7            7   3108588        1    prior             8                   1
# 8            8   2295261        1    prior             9                   1
# 9            9   2550362        1    prior            10                   4
# 10          10   1187899        1    train            11                   4
# ...

# %%
# Step 7)

df_dups = df_ords[df_ords.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, customer_status]
# Index: []

# %% [markdown]
# There doesn't seem to be any duplicates in the orders dataframe.

# %% [markdown]
# Step 8)
#
# We found no duplicates, therefore we don't need to perform any actions.

# %%
# Step 9)

df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checked.csv'))

# %%
df_ords.shape
# Out:
# (3421083, 9)
